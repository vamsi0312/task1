# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\avams\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: setuptools in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (58.0.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.2.1)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.10.0.2)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: packaging in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\avams\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\avams\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\avams\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\avams\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\avams\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\avams\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\avams\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\avams\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\avams\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\avams\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\avams\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avams\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avams\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\avams\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\avams\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\avams\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\avams\anaconda3\lib\site-packages (2.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('Task_1_Stocks_dataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 6s 72ms/step - loss: 0.0101 - mean_absolute_error: 0.0705 - val_loss: 0.0301 - val_mean_absolute_error: 0.1473
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 8.5748e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0056 - val_mean_absolute_error: 0.0558
# Epoch 3/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.9331e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0047 - val_mean_absolute_error: 0.0522
# Epoch 4/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.5499e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0066 - val_mean_absolute_error: 0.0647
# Epoch 5/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.6069e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0051 - val_mean_absolute_error: 0.0540
# Epoch 6/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.5529e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0054 - val_mean_absolute_error: 0.0559
# Epoch 7/100
# 28/28 [==============================] - 1s 35ms/step - loss: 4.0779e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 8/100
# 28/28 [==============================] - 1s 35ms/step - loss: 4.1693e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0085 - val_mean_absolute_error: 0.0748
# Epoch 9/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.2246e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0060 - val_mean_absolute_error: 0.0598
# Epoch 10/100
# 28/28 [==============================] - 1s 29ms/step - loss: 3.9067e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0043 - val_mean_absolute_error: 0.0495
# Epoch 11/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.8438e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0053 - val_mean_absolute_error: 0.0564
# Epoch 12/100
# 28/28 [==============================] - 1s 29ms/step - loss: 3.4467e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0064 - val_mean_absolute_error: 0.0638
# Epoch 13/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.7512e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0038 - val_mean_absolute_error: 0.0467
# Epoch 14/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.4627e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0044 - val_mean_absolute_error: 0.0511
# Epoch 15/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.6953e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0069 - val_mean_absolute_error: 0.0680
# Epoch 16/100
# 28/28 [==============================] - 1s 29ms/step - loss: 3.6469e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0037 - val_mean_absolute_error: 0.0460
# Epoch 17/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.6723e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0027 - val_mean_absolute_error: 0.0383
# Epoch 18/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.6220e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0055 - val_mean_absolute_error: 0.0599
# Epoch 19/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.1830e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 20/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.9469e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0028 - val_mean_absolute_error: 0.0394
# Epoch 21/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.0747e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 22/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.2578e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0052 - val_mean_absolute_error: 0.0575
# Epoch 23/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.8590e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 24/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.9480e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0037 - val_mean_absolute_error: 0.0464
# Epoch 25/100
# 28/28 [==============================] - 1s 26ms/step - loss: 2.9211e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0046 - val_mean_absolute_error: 0.0525
# Epoch 26/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.7091e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0061 - val_mean_absolute_error: 0.0633
# Epoch 27/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.9531e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0024 - val_mean_absolute_error: 0.0363
# Epoch 28/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.8985e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0054 - val_mean_absolute_error: 0.0593
# Epoch 29/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.5390e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0044 - val_mean_absolute_error: 0.0517
# Epoch 30/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5309e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0032 - val_mean_absolute_error: 0.0437
# Epoch 31/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.6463e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0037 - val_mean_absolute_error: 0.0471
# Epoch 32/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.4695e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 33/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.5028e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0038 - val_mean_absolute_error: 0.0481
# Epoch 34/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5360e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0067 - val_mean_absolute_error: 0.0680
# Epoch 35/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5698e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0063 - val_mean_absolute_error: 0.0654
# Epoch 36/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.5902e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0035 - val_mean_absolute_error: 0.0455
# Epoch 37/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.4400e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0036 - val_mean_absolute_error: 0.0473
# Epoch 38/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.3858e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0040 - val_mean_absolute_error: 0.0500
# Epoch 39/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.3699e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.2299e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0033 - val_mean_absolute_error: 0.0442
# Epoch 41/100
# 28/28 [==============================] - 1s 27ms/step - loss: 2.2898e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 42/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.9970e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0022 - val_mean_absolute_error: 0.0359
# Epoch 43/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.1474e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435
# Epoch 44/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.1516e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0018 - val_mean_absolute_error: 0.0314
# Epoch 45/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.0711e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0358
# Epoch 46/100
# 28/28 [==============================] - 1s 26ms/step - loss: 2.2462e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0021 - val_mean_absolute_error: 0.0327
# Epoch 47/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.2403e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0013 - val_mean_absolute_error: 0.0256
# Epoch 48/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.0912e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0035 - val_mean_absolute_error: 0.0466
# Epoch 49/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.9234e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 50/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.0480e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0019 - val_mean_absolute_error: 0.0307
# Epoch 51/100
# 28/28 [==============================] - 1s 27ms/step - loss: 2.2433e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0017 - val_mean_absolute_error: 0.0294
# Epoch 52/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.9743e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0024 - val_mean_absolute_error: 0.0345
# Epoch 53/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.8883e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 54/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.0111e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 55/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7570e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0035 - val_mean_absolute_error: 0.0464
# Epoch 56/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.8034e-04 - mean_absolute_error: 0.0099 - val_loss: 9.1531e-04 - val_mean_absolute_error: 0.0214
# Epoch 57/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.8701e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0271
# Epoch 58/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.8169e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0019 - val_mean_absolute_error: 0.0288
# Epoch 59/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.8017e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 60/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.7944e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0223
# Epoch 61/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.8553e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 62/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.7332e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0023 - val_mean_absolute_error: 0.0334
# Epoch 63/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.6709e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0025 - val_mean_absolute_error: 0.0343
# Epoch 64/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.6602e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0050 - val_mean_absolute_error: 0.0513
# Epoch 65/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5646e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0024 - val_mean_absolute_error: 0.0367
# Epoch 66/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5816e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0033 - val_mean_absolute_error: 0.0431
# Epoch 67/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5450e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0027 - val_mean_absolute_error: 0.0333
# Epoch 68/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5422e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0038 - val_mean_absolute_error: 0.0447
# Epoch 69/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5402e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0029 - val_mean_absolute_error: 0.0354
# Epoch 70/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5237e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0040 - val_mean_absolute_error: 0.0406
# Epoch 71/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5631e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0019 - val_mean_absolute_error: 0.0290
# Epoch 72/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5120e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0027 - val_mean_absolute_error: 0.0330
# Epoch 73/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5040e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0042 - val_mean_absolute_error: 0.0442
# Epoch 74/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5830e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0038 - val_mean_absolute_error: 0.0421
# Epoch 75/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.4694e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0040 - val_mean_absolute_error: 0.0462
# Epoch 76/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.4685e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0059 - val_mean_absolute_error: 0.0558
# Epoch 77/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.5452e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0019 - val_mean_absolute_error: 0.0314
# Epoch 78/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6137e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0047 - val_mean_absolute_error: 0.0520
# Epoch 79/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5429e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0030 - val_mean_absolute_error: 0.0370
# Epoch 80/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.5290e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0023 - val_mean_absolute_error: 0.0333
# Epoch 81/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3610e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0031 - val_mean_absolute_error: 0.0361
# Epoch 82/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.4766e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0045 - val_mean_absolute_error: 0.0501
# Epoch 83/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.3373e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0029 - val_mean_absolute_error: 0.0347
# Epoch 84/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.3615e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0027 - val_mean_absolute_error: 0.0335
# Epoch 85/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2518e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0047 - val_mean_absolute_error: 0.0472
# Epoch 86/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3437e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0040 - val_mean_absolute_error: 0.0465
# Epoch 87/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5513e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0034 - val_mean_absolute_error: 0.0423
# Epoch 88/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.3547e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0044 - val_mean_absolute_error: 0.0470
# Epoch 89/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.2771e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0021 - val_mean_absolute_error: 0.0285
# Epoch 90/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.2543e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 91/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.2522e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0028 - val_mean_absolute_error: 0.0356
# Epoch 92/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.2416e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0270
# Epoch 93/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.4493e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0029 - val_mean_absolute_error: 0.0353
# Epoch 94/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5420e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0036 - val_mean_absolute_error: 0.0442
# Epoch 95/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.1688e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0026 - val_mean_absolute_error: 0.0326
# Epoch 96/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.2750e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0028 - val_mean_absolute_error: 0.0337
# Epoch 97/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2813e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0021 - val_mean_absolute_error: 0.0317
# Epoch 98/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3572e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0022 - val_mean_absolute_error: 0.0313
# Epoch 99/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.1691e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0026 - val_mean_absolute_error: 0.0342
# Epoch 100/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2234e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 8ms/step
# array([[0.40259525, 0.4007594 ],
#        [0.40255165, 0.40068996],
#        [0.396705  , 0.39500156],
#        [0.39921853, 0.39743495],
#        [0.40314233, 0.40133083]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1417.3794, 1411.0034],
#        [1417.2986, 1410.8748],
#        [1406.4592, 1400.3322],
#        [1411.1191, 1404.8422],
#        [1418.3937, 1412.0625]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1417.379395      1411.003418
# 2020-05-28  1396.86  1416.73     1417.298584      1410.874756
# 2020-05-29  1416.94  1428.92     1406.459229      1400.332153
# 2020-06-01  1418.39  1431.82     1411.119141      1404.842163
# 2020-06-02  1430.55  1439.22     1418.393677      1412.062500

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2511.277588      2254.930176
# 2021-06-10  2494.01  2521.60     2524.111572      2262.517090
# 2021-06-11  2524.92  2513.93     2532.231689      2266.182129
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
